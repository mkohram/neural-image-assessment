# %%
import numpy as np
import argparse
from path import Path

from keras.models import Model
from keras.layers import Dense, Dropout
from keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import tensorflow as tf
import glob
import subprocess
import pickle
import PIL as p
from multiprocessing import Pool
import warnings

from utils.nasnet import NASNetMobile, preprocess_input
from utils.score_utils import mean_score, std_score

import logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(name)s - %(levelname)s - %(message)s')
logger = logging.getLogger()

doms = glob.glob("/nn-images/images_split_by_domain/domains/*")

# %%
ims = pickle.load(open('image_order.pickle', "rb"))
img_dct = pickle.load(open('image_dct.picke', "rb"))

# %%
import time
from multiprocessing import Pool

def image_checker(impath):
    try:
        img = load_img(impath, target_size=RESHAPE_SIZE)
    except OSError:
        return impath, None

    try:
        x = img_to_array(img)
    except TypeError:
        return impath, None
    
    return impath, x

def filtered_data_generator(batch_size, paths):
    batch_paths = []
    batch = []
    with Pool(15) as pool:
        for imcheck in pool.imap_unordered(image_checker, paths):
            if imcheck[1] is None:
                logger.warning(f'Failed validation for {imcheck[0]}. skipping.')
                continue

            batch.append(imcheck[1])
            batch_paths.append(imcheck[0])
            
            if len(batch) == batch_size:
                data_batch = preprocess_input(np.stack(batch))
                yield data_batch, batch_paths
                
                batch_paths = []
                batch = []
        
        data_batch = preprocess_input(np.stack(batch))
        yield data_batch, batch_paths

def nn_data_generator(batch_size):
    all_paths = []
    for idx, data_batch_paths in enumerate(filtered_data_generator(batch_size, INPUT_PATHS)):
        data_batch, paths = data_batch_paths
        logger.info(f'produced batch {idx+1}')
        all_paths += paths

        with open('/nn-images/filenames/all_paths.pkl', 'wb') as f:
            pickle.dump(all_paths, f)
        
        yield data_batch

# %%
with tf.device('/GPU:0'):
    logger.info('building nn')
    base_model = NASNetMobile((224, 224, 3), include_top=False, pooling='avg', weights=None)
    x = Dropout(0.75)(base_model.output)
    x = Dense(10, activation='softmax')(x)

    model = Model(base_model.input, x)
    model.load_weights('weights/nasnet_weights.h5')
# Out:
# 2018-08-30 18:24:46,924 - root - INFO - building nn

# %%
gap = 10000
for startidx in range(0, 800000, gap):
    endidx = startidx+gap
    INPUT_PATHS = ims[startidx:endidx]
    RESHAPE_SIZE = (224, 224)

    logger.info(f'running images through nn ({startidx}-{endidx})')

    if len(INPUT_PATHS) == gap:
        gen_count = int(gap/1000)
    else:
        gen_count = int(gap/1000) + 1

    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        scores = model.predict_generator(nn_data_generator(1000), gen_count, verbose=2, workers=0)

    with open('/nn-images/filenames/all_paths.pkl', 'rb') as f:
        scored_paths = pickle.load(f)

    assert scores.shape[0] == len(scored_paths)

    with open(f'/nn-images/image_scores/scores.{endidx:06}.pkl', 'wb') as f:
        pickle.dump((scores, scored_paths), f)
# Out:
# 2018-08-30 18:29:54,382 - root - INFO - running images through nn (0-10000)
# 2018-08-30 18:30:07,721 - root - INFO - produced batch 1
# 2018-08-30 18:30:23,914 - root - INFO - produced batch 2
# 2018-08-30 18:30:28,295 - root - INFO - produced batch 3
# 2018-08-30 18:30:32,714 - root - INFO - produced batch 4
# 2018-08-30 18:30:37,199 - root - INFO - produced batch 5
# 2018-08-30 18:30:46,550 - root - INFO - produced batch 6
# 2018-08-30 18:30:53,163 - root - INFO - produced batch 7
# 2018-08-30 18:30:59,912 - root - INFO - produced batch 8
# 2018-08-30 18:31:05,855 - root - INFO - produced batch 9
# 2018-08-30 18:31:10,980 - root - INFO - produced batch 10
# 2018-08-30 18:31:14,943 - root - INFO - running images through nn (10000-20000)
# 2018-08-30 18:31:21,261 - root - INFO - produced batch 1
# 2018-08-30 18:31:25,700 - root - INFO - produced batch 2
# 2018-08-30 18:31:30,078 - root - INFO - produced batch 3
# 2018-08-30 18:31:42,568 - root - INFO - produced batch 4
# 2018-08-30 18:31:56,522 - root - INFO - produced batch 5
# 2018-08-30 18:32:06,518 - root - INFO - produced batch 6
# 2018-08-30 18:32:12,263 - root - INFO - produced batch 7
# 2018-08-30 18:32:18,736 - root - INFO - produced batch 8
# 2018-08-30 18:32:25,070 - root - INFO - produced batch 9
# 2018-08-30 18:32:33,264 - root - INFO - produced batch 10
# 2018-08-30 18:32:37,345 - root - INFO - running images through nn (20000-30000)
# 2018-08-30 18:32:49,428 - root - INFO - produced batch 1
# 2018-08-30 18:32:58,890 - root - INFO - produced batch 2
# 2018-08-30 18:33:04,890 - root - INFO - produced batch 3
# 2018-08-30 18:33:11,166 - root - INFO - produced batch 4
# 2018-08-30 18:33:16,522 - root - INFO - produced batch 5
# 2018-08-30 18:33:21,414 - root - INFO - produced batch 6
# 2018-08-30 18:33:27,555 - root - INFO - produced batch 7
# 2018-08-30 18:33:31,986 - root - INFO - produced batch 8
# 2018-08-30 18:33:39,312 - root - INFO - produced batch 9
# 2018-08-30 18:33:47,451 - root - INFO - produced batch 10
# 2018-08-30 18:33:51,552 - root - INFO - running images through nn (30000-40000)
# 2018-08-30 18:33:59,851 - root - INFO - produced batch 1
# 2018-08-30 18:34:04,324 - root - INFO - produced batch 2
# 2018-08-30 18:34:11,770 - root - INFO - produced batch 3
# 2018-08-30 18:34:16,169 - root - INFO - produced batch 4
# 2018-08-30 18:34:25,896 - root - INFO - produced batch 5
# 2018-08-30 18:34:58,845 - root - INFO - produced batch 6
# 2018-08-30 18:35:30,822 - root - INFO - produced batch 7
# 2018-08-30 18:35:35,435 - root - INFO - produced batch 8
# 2018-08-30 18:35:39,899 - root - INFO - produced batch 9
# 2018-08-30 18:35:44,230 - root - INFO - produced batch 10
# 2018-08-30 18:35:48,370 - root - INFO - running images through nn (40000-50000)
# 2018-08-30 18:35:53,148 - root - INFO - produced batch 1
# 2018-08-30 18:35:57,817 - root - INFO - produced batch 2
# 2018-08-30 18:36:02,242 - root - INFO - produced batch 3
# 2018-08-30 18:36:08,420 - root - INFO - produced batch 4
# 2018-08-30 18:36:14,522 - root - INFO - produced batch 5
# 2018-08-30 18:36:23,771 - root - INFO - produced batch 6
# 2018-08-30 18:36:31,516 - root - INFO - produced batch 7
# 2018-08-30 18:36:41,913 - root - INFO - produced batch 8
# 2018-08-30 18:36:52,298 - root - INFO - produced batch 9
# 2018-08-30 18:37:00,506 - root - INFO - produced batch 10
# 2018-08-30 18:37:04,594 - root - INFO - running images through nn (50000-60000)
# 2018-08-30 18:37:10,974 - root - INFO - produced batch 1
# 2018-08-30 18:37:19,331 - root - INFO - produced batch 2
# 2018-08-30 18:37:24,930 - root - INFO - produced batch 3
# 2018-08-30 18:37:29,290 - root - INFO - produced batch 4
# 2018-08-30 18:37:34,822 - root - INFO - produced batch 5
# 2018-08-30 18:37:39,537 - root - INFO - produced batch 6
# 2018-08-30 18:37:43,993 - root - INFO - produced batch 7
# 2018-08-30 18:37:48,356 - root - INFO - produced batch 8
# 2018-08-30 18:37:52,648 - root - INFO - produced batch 9
# 2018-08-30 18:37:56,928 - root - INFO - produced batch 10
# 2018-08-30 18:38:00,969 - root - INFO - running images through nn (60000-70000)
# 2018-08-30 18:38:07,999 - root - INFO - produced batch 1
# 2018-08-30 18:38:12,706 - root - INFO - produced batch 2
# 2018-08-30 18:38:18,798 - root - INFO - produced batch 3
# 2018-08-30 18:38:25,299 - root - INFO - produced batch 4
# 2018-08-30 18:38:32,489 - root - INFO - produced batch 5
# 2018-08-30 18:38:38,636 - root - INFO - produced batch 6
# 2018-08-30 18:38:43,036 - root - INFO - produced batch 7
# 2018-08-30 18:38:55,431 - root - INFO - produced batch 8
# 2018-08-30 18:39:02,935 - root - INFO - produced batch 9
# 2018-08-30 18:39:07,395 - root - INFO - produced batch 10
# 2018-08-30 18:39:11,441 - root - INFO - running images through nn (70000-80000)
# 2018-08-30 18:39:17,618 - root - INFO - produced batch 1
# 2018-08-30 18:39:23,810 - root - INFO - produced batch 2
# 2018-08-30 18:39:28,246 - root - INFO - produced batch 3
# 2018-08-30 18:39:34,042 - root - INFO - produced batch 4
# 2018-08-30 18:39:40,516 - root - INFO - produced batch 5
# 2018-08-30 18:39:47,624 - root - INFO - produced batch 6
# 2018-08-30 18:40:10,483 - root - INFO - produced batch 7
# 2018-08-30 18:40:16,874 - root - INFO - produced batch 8
# 2018-08-30 18:40:21,289 - root - INFO - produced batch 9
# 2018-08-30 18:40:27,601 - root - INFO - produced batch 10
# 2018-08-30 18:40:31,664 - root - INFO - running images through nn (80000-90000)
# 2018-08-30 18:40:43,699 - root - INFO - produced batch 1
# 2018-08-30 18:40:56,432 - root - INFO - produced batch 2
# 2018-08-30 18:41:05,296 - root - INFO - produced batch 3
# 2018-08-30 18:41:09,984 - root - INFO - produced batch 4
# 2018-08-30 18:41:18,254 - root - INFO - produced batch 5
# 2018-08-30 18:41:25,410 - root - INFO - produced batch 6
# 2018-08-30 18:41:32,528 - root - INFO - produced batch 7
# 2018-08-30 18:41:38,229 - root - INFO - produced batch 8
# 2018-08-30 18:41:44,193 - root - INFO - produced batch 9
# 2018-08-30 18:41:48,987 - root - INFO - produced batch 10
# 2018-08-30 18:41:53,036 - root - INFO - running images through nn (90000-100000)
# 2018-08-30 18:41:58,692 - root - INFO - produced batch 1
# 2018-08-30 18:42:03,170 - root - INFO - produced batch 2
# 2018-08-30 18:42:11,950 - root - INFO - produced batch 3
# 2018-08-30 18:42:16,472 - root - INFO - produced batch 4
# 2018-08-30 18:42:28,058 - root - INFO - produced batch 5
# 2018-08-30 18:42:32,422 - root - INFO - produced batch 6
# 2018-08-30 18:42:40,992 - root - INFO - produced batch 7
# 2018-08-30 18:42:48,898 - root - INFO - produced batch 8
# 2018-08-30 18:42:54,488 - root - INFO - produced batch 9
# 2018-08-30 18:42:58,783 - root - INFO - produced batch 10
# 2018-08-30 18:43:02,818 - root - INFO - running images through nn (100000-110000)
# 2018-08-30 18:43:07,464 - root - INFO - produced batch 1
# 2018-08-30 18:43:12,117 - root - INFO - produced batch 2
# 2018-08-30 18:43:23,814 - root - INFO - produced batch 3
# 2018-08-30 18:43:28,863 - root - INFO - produced batch 4
# 2018-08-30 18:43:38,477 - root - INFO - produced batch 5
# 2018-08-30 18:43:50,891 - root - INFO - produced batch 6
# 2018-08-30 18:43:55,471 - root - INFO - produced batch 7
# 2018-08-30 18:43:59,914 - root - INFO - produced batch 8
# 2018-08-30 18:44:04,378 - root - INFO - produced batch 9
# 2018-08-30 18:44:08,697 - root - INFO - produced batch 10
# 2018-08-30 18:44:12,824 - root - INFO - running images through nn (110000-120000)
# 2018-08-30 18:44:18,239 - root - INFO - produced batch 1
# 2018-08-30 18:44:23,883 - root - INFO - produced batch 2
# 2018-08-30 18:44:29,342 - root - INFO - produced batch 3
# 2018-08-30 18:44:33,760 - root - INFO - produced batch 4
# 2018-08-30 18:44:39,225 - root - INFO - produced batch 5
# 2018-08-30 18:44:46,426 - root - INFO - produced batch 6
# 2018-08-30 18:44:50,972 - root - INFO - produced batch 7
# 2018-08-30 18:44:55,391 - root - INFO - produced batch 8
# 2018-08-30 18:44:59,778 - root - INFO - produced batch 9
# 2018-08-30 18:45:04,132 - root - INFO - produced batch 10
# 2018-08-30 18:45:08,217 - root - INFO - running images through nn (120000-130000)
# 2018-08-30 18:45:14,926 - root - INFO - produced batch 1
# 2018-08-30 18:45:19,403 - root - INFO - produced batch 2
# 2018-08-30 18:45:35,334 - root - INFO - produced batch 3
# 2018-08-30 18:45:39,891 - root - INFO - produced batch 4
# 2018-08-30 18:45:44,248 - root - INFO - produced batch 5
# 2018-08-30 18:45:48,167 - root - WARNING - Failed validation for /nn-images/images_split_by_domain/domains/sweetcsdesigns.com/2018-02-24-620bf22a97a0d311f29ac3ae5f2448cd62699b7e.jpg. skipping.
# 2018-08-30 18:45:48,171 - root - WARNING - Failed validation for /nn-images/images_split_by_domain/domains/sweetcsdesigns.com/2018-03-08-6d3adae2636f915c89812f8104677e193585e026.jpg. skipping.
# 2018-08-30 18:45:48,173 - root - WARNING - Failed validation for /nn-images/images_split_by_domain/domains/sweetcsdesigns.com/2018-03-08-08ecf3334be5a185ad14f44eb058b58647e0bdde.jpg. skipping.
# 2018-08-30 18:45:48,174 - root - WARNING - Failed validation for /nn-images/images_split_by_domain/domains/sweetcsdesigns.com/2017-11-07-b8934f0b122199f8b42de5dfca6c80c1b4cdcf8a.jpg. skipping.
# 2018-08-30 18:45:48,175 - root - WARNING - Failed validation for /nn-images/images_split_by_domain/domains/sweetcsdesigns.com/2018-05-04-09ee96f03f560362c9a5341400ea2bddf6ec758e.jpg. skipping.
# 2018-08-30 18:45:48,179 - root - WARNING - Failed validation for /nn-images/images_split_by_domain/domains/sweetcsdesigns.com/2018-05-04-b1dda11281eba4161621116125c671872be37077.jpg. skipping.
# 2018-08-30 18:45:48,180 - root - WARNING - Failed validation for /nn-images/images_split_by_domain/domains/sweetcsdesigns.com/2018-02-08-c46610a3f93678d5562c2fd24b12ebf67c96badc.jpg. skipping.
# 2018-08-30 18:45:49,378 - root - INFO - produced batch 6
# 2018-08-30 18:45:58,554 - root - INFO - produced batch 7
# 2018-08-30 18:46:05,538 - root - INFO - produced batch 8
# 2018-08-30 18:46:13,088 - root - INFO - produced batch 9
# 2018-08-30 18:46:20,401 - root - INFO - produced batch 10
# 2018-08-30 18:46:26,377 - root - INFO - running images through nn (130000-140000)
# 2018-08-30 18:46:43,552 - root - WARNING - Failed validation for /nn-images/images_split_by_domain/domains/forthelove.blog/2018-01-04-26644a80629a803f0515d788dc5ff2b5663862b0.jpg. skipping.
# 2018-08-30 18:46:50,064 - root - WARNING - Failed validation for /nn-images/images_split_by_domain/domains/forthelove.blog/2018-01-04-f14f39ed665dbc222d4b0484d347e760facbab59.jpg. skipping.
# 2018-08-30 18:46:50,080 - root - WARNING - Failed validation for /nn-images/images_split_by_domain/domains/forthelove.blog/2018-01-04-b9ba7565b8c7849d395de7c3318332c6a3b5574f.jpg. skipping.
# 2018-08-30 18:46:52,410 - root - WARNING - Failed validation for /nn-images/images_split_by_domain/domains/forthelove.blog/2018-01-04-04c9ab2225d59279b846f405829578bc8153da1c.jpg. skipping.
# 2018-08-30 18:46:53,985 - root - INFO - produced batch 1
# 2018-08-30 18:47:04,498 - root - INFO - produced batch 2
# 2018-08-30 18:47:14,451 - root - INFO - produced batch 3
# 2018-08-30 18:47:20,175 - root - INFO - produced batch 4
# 2018-08-30 18:47:26,150 - root - INFO - produced batch 5
# 2018-08-30 18:47:31,958 - root - INFO - produced batch 6
# 2018-08-30 18:47:37,826 - root - INFO - produced batch 7
# 2018-08-30 18:47:46,427 - root - INFO - produced batch 8
# 2018-08-30 18:47:50,918 - root - INFO - produced batch 9
# 2018-08-30 18:48:01,619 - root - INFO - produced batch 10
# 2018-08-30 18:48:07,817 - root - INFO - running images through nn (140000-150000)
# 2018-08-30 18:48:24,179 - root - INFO - produced batch 1
# 2018-08-30 18:48:42,250 - root - INFO - produced batch 2
# 2018-08-30 18:48:46,615 - root - INFO - produced batch 3
# 2018-08-30 18:48:50,964 - root - INFO - produced batch 4
# 2018-08-30 18:48:55,323 - root - INFO - produced batch 5
# 2018-08-30 18:48:59,706 - root - INFO - produced batch 6
# 2018-08-30 18:49:06,122 - root - INFO - produced batch 7
# 2018-08-30 18:49:13,535 - root - INFO - produced batch 8
# 2018-08-30 18:49:20,314 - root - INFO - produced batch 9
# 2018-08-30 18:49:25,729 - root - INFO - produced batch 10
# 2018-08-30 18:49:29,802 - root - INFO - running images through nn (150000-160000)
# 2018-08-30 18:49:36,857 - root - INFO - produced batch 1
# 2018-08-30 18:49:41,431 - root - INFO - produced batch 2
# 2018-08-30 18:49:56,528 - root - INFO - produced batch 3
# 2018-08-30 18:50:12,234 - root - INFO - produced batch 4
# 2018-08-30 18:50:21,343 - root - INFO - produced batch 5
# 2018-08-30 18:50:28,047 - root - INFO - produced batch 6
# 2018-08-30 18:50:36,378 - root - INFO - produced batch 7
# 2018-08-30 18:50:44,510 - root - INFO - produced batch 8
# 2018-08-30 18:50:49,270 - root - INFO - produced batch 9
# 2018-08-30 18:50:55,914 - root - INFO - produced batch 10
# 2018-08-30 18:51:00,217 - root - INFO - running images through nn (160000-170000)
# 2018-08-30 18:51:05,971 - root - INFO - produced batch 1
# 2018-08-30 18:51:11,086 - root - INFO - produced batch 2
# 2018-08-30 18:51:16,462 - root - INFO - produced batch 3
# 2018-08-30 18:51:23,139 - root - INFO - produced batch 4
# 2018-08-30 18:51:27,520 - root - INFO - produced batch 5
# 2018-08-30 18:51:33,028 - root - INFO - produced batch 6
# 2018-08-30 18:51:41,991 - root - INFO - produced batch 7
# 2018-08-30 18:51:47,810 - root - INFO - produced batch 8
# 2018-08-30 18:51:52,928 - root - INFO - produced batch 9
# 2018-08-30 18:51:57,292 - root - INFO - produced batch 10
# 2018-08-30 18:52:01,298 - root - INFO - running images through nn (170000-180000)
# 2018-08-30 18:52:06,466 - root - INFO - produced batch 1
# 2018-08-30 18:52:11,114 - root - INFO - produced batch 2
# 2018-08-30 18:52:15,490 - root - INFO - produced batch 3
# 2018-08-30 18:52:19,842 - root - INFO - produced batch 4
# 2018-08-30 18:52:30,508 - root - INFO - produced batch 5
# 2018-08-30 18:52:36,722 - root - INFO - produced batch 6
# 2018-08-30 18:52:46,504 - root - INFO - produced batch 7
# 2018-08-30 18:52:53,422 - root - INFO - produced batch 8
# 2018-08-30 18:52:57,572 - root - WARNING - Failed validation for /nn-images/images_split_by_domain/domains/reelmama.com/2015-02-26-fdcd5bf5db0751936859c46950b8aaa640228169.jpg. skipping.
# 2018-08-30 18:53:02,220 - root - INFO - produced batch 9
# 2018-08-30 18:53:07,305 - root - INFO - produced batch 10
# 2018-08-30 18:53:13,324 - root - INFO - running images through nn (180000-190000)
# 2018-08-30 18:53:20,308 - root - INFO - produced batch 1
# 2018-08-30 18:53:28,912 - root - INFO - produced batch 2
# 2018-08-30 18:53:40,018 - root - INFO - produced batch 3
# 2018-08-30 18:53:44,606 - root - INFO - produced batch 4
# 2018-08-30 18:53:50,701 - root - INFO - produced batch 5
# 2018-08-30 18:54:01,333 - root - INFO - produced batch 6
# 2018-08-30 18:54:07,082 - root - INFO - produced batch 7
# 2018-08-30 18:54:11,914 - root - INFO - produced batch 8
# 2018-08-30 18:54:19,798 - root - INFO - produced batch 9
# 2018-08-30 18:54:48,446 - root - INFO - produced batch 10
# 2018-08-30 18:54:52,739 - root - INFO - running images through nn (190000-200000)
# 2018-08-30 18:54:59,819 - root - INFO - produced batch 1
# 2018-08-30 18:55:04,294 - root - INFO - produced batch 2
# 2018-08-30 18:55:08,989 - root - INFO - produced batch 3
# 2018-08-30 18:55:14,948 - root - INFO - produced batch 4
# 2018-08-30 18:55:19,278 - root - INFO - produced batch 5
# 2018-08-30 18:55:23,636 - root - INFO - produced batch 6
# 2018-08-30 18:55:28,486 - root - INFO - produced batch 7
# 2018-08-30 18:55:33,127 - root - INFO - produced batch 8
# 2018-08-30 18:55:37,552 - root - INFO - produced batch 9
# 2018-08-30 18:55:41,855 - root - INFO - produced batch 10
# 2018-08-30 18:55:45,900 - root - INFO - running images through nn (200000-210000)
# 2018-08-30 18:55:52,035 - root - INFO - produced batch 1
# 2018-08-30 18:55:56,682 - root - INFO - produced batch 2
# 2018-08-30 18:56:03,143 - root - INFO - produced batch 3
# 2018-08-30 18:56:11,512 - root - INFO - produced batch 4
# 2018-08-30 18:56:16,408 - root - INFO - produced batch 5
# 2018-08-30 18:56:38,846 - root - INFO - produced batch 6
# 2018-08-30 18:56:43,431 - root - INFO - produced batch 7
# 2018-08-30 18:56:47,846 - root - INFO - produced batch 8
# 2018-08-30 18:56:52,212 - root - INFO - produced batch 9
# 2018-08-30 18:56:56,588 - root - INFO - produced batch 10
# 2018-08-30 18:57:00,649 - root - INFO - running images through nn (210000-220000)
# 2018-08-30 18:57:07,175 - root - INFO - produced batch 1
# 2018-08-30 18:57:14,629 - root - WARNING - Failed validation for /nn-images/images_split_by_domain/domains/culturewithcoco.com/2016-10-25-3f3c881d2f4c7ad7dcec800bf5b8cd8f3ba2c4df.jpg. skipping.
# 2018-08-30 18:57:18,670 - root - INFO - produced batch 2
# 2018-08-30 18:57:25,622 - root - INFO - produced batch 3
# 2018-08-30 18:57:30,190 - root - INFO - produced batch 4
# 2018-08-30 18:57:36,385 - root - INFO - produced batch 5
# 2018-08-30 18:57:44,698 - root - INFO - produced batch 6
# 2018-08-30 18:57:51,395 - root - INFO - produced batch 7
# 2018-08-30 18:57:55,780 - root - INFO - produced batch 8
# 2018-08-30 18:58:06,370 - root - INFO - produced batch 9
# 2018-08-30 18:58:15,584 - root - INFO - produced batch 10
# 2018-08-30 18:58:19,791 - root - INFO - running images through nn (220000-230000)
# 2018-08-30 18:58:25,578 - root - INFO - produced batch 1
# 2018-08-30 18:58:33,923 - root - INFO - produced batch 2
# 2018-08-30 18:58:46,514 - root - INFO - produced batch 3
# 2018-08-30 18:58:53,646 - root - INFO - produced batch 4
# 2018-08-30 18:59:01,318 - root - INFO - produced batch 5
# 2018-08-30 18:59:05,877 - root - INFO - produced batch 6
# 2018-08-30 18:59:22,843 - root - INFO - produced batch 7
# 2018-08-30 18:59:34,574 - root - INFO - produced batch 8
# 2018-08-30 18:59:38,935 - root - INFO - produced batch 9
# 2018-08-30 18:59:45,567 - root - INFO - produced batch 10
# 2018-08-30 18:59:49,719 - root - INFO - running images through nn (230000-240000)
# 2018-08-30 18:59:55,679 - root - INFO - produced batch 1
# 2018-08-30 19:00:00,160 - root - INFO - produced batch 2
# 2018-08-30 19:00:07,962 - root - INFO - produced batch 3
# 2018-08-30 19:00:12,359 - root - INFO - produced batch 4
# 2018-08-30 19:00:21,950 - root - INFO - produced batch 5
# 2018-08-30 19:00:26,398 - root - INFO - produced batch 6
# 2018-08-30 19:00:31,598 - root - INFO - produced batch 7
# 2018-08-30 19:00:38,649 - root - INFO - produced batch 8
# 2018-08-30 19:00:44,530 - root - INFO - produced batch 9
# 2018-08-30 19:00:51,247 - root - INFO - produced batch 10
# 2018-08-30 19:00:55,416 - root - INFO - running images through nn (240000-250000)
# 2018-08-30 19:01:02,959 - root - INFO - produced batch 1
# 2018-08-30 19:01:12,412 - root - INFO - produced batch 2
# 2018-08-30 19:01:17,891 - root - INFO - produced batch 3
# 2018-08-30 19:01:23,490 - root - INFO - produced batch 4
# 2018-08-30 19:01:28,897 - root - INFO - produced batch 5
# 2018-08-30 19:01:35,155 - root - INFO - produced batch 6
# 2018-08-30 19:01:43,573 - root - INFO - produced batch 7
# 2018-08-30 19:01:49,816 - root - INFO - produced batch 8
# 2018-08-30 19:01:57,262 - root - INFO - produced batch 9
# 2018-08-30 19:02:02,896 - root - INFO - produced batch 10
# 2018-08-30 19:02:06,978 - root - INFO - running images through nn (250000-260000)
# 2018-08-30 19:02:13,790 - root - INFO - produced batch 1
# 2018-08-30 19:02:28,030 - root - INFO - produced batch 2
# 2018-08-30 19:02:32,030 - root - WARNING - Failed validation for /nn-images/images_split_by_domain/domains/littlebloginthecountry.com/2016-05-03-1dbcc5dbf39690c6a3087278ac8f487657b6d042.jpg. skipping.
# 2018-08-30 19:02:33,463 - root - INFO - produced batch 3
# 2018-08-30 19:02:40,991 - root - INFO - produced batch 4
# 2018-08-30 19:02:46,556 - root - INFO - produced batch 5
# 2018-08-30 19:02:53,538 - root - INFO - produced batch 6
# 2018-08-30 19:02:57,979 - root - INFO - produced batch 7
# 2018-08-30 19:03:14,270 - root - INFO - produced batch 8
# 2018-08-30 19:03:19,018 - root - INFO - produced batch 9
# 2018-08-30 19:03:24,304 - root - INFO - produced batch 10
# 2018-08-30 19:03:28,350 - root - INFO - running images through nn (260000-270000)
# 2018-08-30 19:03:35,591 - root - INFO - produced batch 1
# 2018-08-30 19:03:42,914 - root - INFO - produced batch 2
# 2018-08-30 19:03:47,654 - root - INFO - produced batch 3
# 2018-08-30 19:03:54,005 - root - INFO - produced batch 4
# 2018-08-30 19:04:03,590 - root - INFO - produced batch 5
# 2018-08-30 19:04:10,938 - root - INFO - produced batch 6
# 2018-08-30 19:04:16,355 - root - INFO - produced batch 7
# 2018-08-30 19:04:22,470 - root - INFO - produced batch 8
# 2018-08-30 19:04:28,074 - root - INFO - produced batch 9
# 2018-08-30 19:04:33,514 - root - INFO - produced batch 10
# 2018-08-30 19:04:37,643 - root - INFO - running images through nn (270000-280000)
# 2018-08-30 19:04:46,582 - root - INFO - produced batch 1
# 2018-08-30 19:04:55,772 - root - INFO - produced batch 2
# 2018-08-30 19:05:02,127 - root - INFO - produced batch 3
# 2018-08-30 19:05:08,854 - root - INFO - produced batch 4
# 2018-08-30 19:05:15,605 - root - INFO - produced batch 5
# 2018-08-30 19:05:21,831 - root - INFO - produced batch 6
# 2018-08-30 19:05:28,282 - root - INFO - produced batch 7
# 2018-08-30 19:05:34,614 - root - INFO - produced batch 8
# 2018-08-30 19:05:40,986 - root - INFO - produced batch 9
# 2018-08-30 19:05:57,516 - root - INFO - produced batch 10
# 2018-08-30 19:06:01,619 - root - INFO - running images through nn (280000-290000)
# 2018-08-30 19:06:11,715 - root - INFO - produced batch 1
# 2018-08-30 19:06:20,008 - root - INFO - produced batch 2
# 2018-08-30 19:06:24,639 - root - INFO - produced batch 3
# 2018-08-30 19:06:32,430 - root - INFO - produced batch 4
# 2018-08-30 19:06:37,359 - root - INFO - produced batch 5
# 2018-08-30 19:06:45,081 - root - INFO - produced batch 6
# 2018-08-30 19:06:50,060 - root - INFO - produced batch 7
# 2018-08-30 19:06:57,133 - root - INFO - produced batch 8
# 2018-08-30 19:07:02,426 - root - INFO - produced batch 9
# 2018-08-30 19:07:08,580 - root - INFO - produced batch 10
# 2018-08-30 19:07:12,708 - root - INFO - running images through nn (290000-300000)
# 2018-08-30 19:07:20,047 - root - INFO - produced batch 1
# 2018-08-30 19:07:37,287 - root - INFO - produced batch 2
# 2018-08-30 19:07:45,874 - root - INFO - produced batch 3
# 2018-08-30 19:07:55,222 - root - INFO - produced batch 4
# 2018-08-30 19:08:04,084 - root - INFO - produced batch 5
# 2018-08-30 19:08:09,966 - root - INFO - produced batch 6
# 2018-08-30 19:08:21,424 - root - INFO - produced batch 7
# 2018-08-30 19:09:00,867 - root - INFO - produced batch 8
# 2018-08-30 19:09:17,944 - root - INFO - produced batch 9
# 2018-08-30 19:09:27,491 - root - INFO - produced batch 10
# 2018-08-30 19:09:31,591 - root - INFO - running images through nn (300000-310000)
# 2018-08-30 19:09:40,696 - root - INFO - produced batch 1
# 2018-08-30 19:09:45,870 - root - INFO - produced batch 2
# 2018-08-30 19:09:53,768 - root - INFO - produced batch 3
# 2018-08-30 19:10:04,341 - root - INFO - produced batch 4
# 2018-08-30 19:10:09,858 - root - INFO - produced batch 5
# 2018-08-30 19:10:14,217 - root - INFO - produced batch 6
# 2018-08-30 19:10:20,451 - root - INFO - produced batch 7
# 2018-08-30 19:10:28,871 - root - INFO - produced batch 8
# 2018-08-30 19:10:35,277 - root - INFO - produced batch 9
# 2018-08-30 19:10:40,025 - root - INFO - produced batch 10
# 2018-08-30 19:10:44,100 - root - INFO - running images through nn (310000-320000)
# 2018-08-30 19:10:50,261 - root - INFO - produced batch 1
# 2018-08-30 19:10:55,304 - root - INFO - produced batch 2
# 2018-08-30 19:11:04,722 - root - INFO - produced batch 3
# 2018-08-30 19:11:20,188 - root - INFO - produced batch 4
# 2018-08-30 19:11:27,374 - root - INFO - produced batch 5
# 2018-08-30 19:11:39,821 - root - INFO - produced batch 6
# 2018-08-30 19:11:53,739 - root - INFO - produced batch 7
# 2018-08-30 19:11:59,247 - root - INFO - produced batch 8
# 2018-08-30 19:12:04,016 - root - INFO - produced batch 9
# 2018-08-30 19:12:09,409 - root - INFO - produced batch 10
# 2018-08-30 19:12:13,460 - root - INFO - running images through nn (320000-330000)
# 2018-08-30 19:12:19,624 - root - INFO - produced batch 1
# 2018-08-30 19:12:27,134 - root - INFO - produced batch 2
# 2018-08-30 19:12:37,223 - root - INFO - produced batch 3
# 2018-08-30 19:12:43,755 - root - INFO - produced batch 4
# 2018-08-30 19:12:49,774 - root - INFO - produced batch 5
# 2018-08-30 19:12:55,762 - root - INFO - produced batch 6
# 2018-08-30 19:13:02,336 - root - INFO - produced batch 7
# 2018-08-30 19:13:16,314 - root - INFO - produced batch 8
# 2018-08-30 19:13:24,552 - root - INFO - produced batch 9
# 2018-08-30 19:13:29,591 - root - INFO - produced batch 10
# 2018-08-30 19:13:33,641 - root - INFO - running images through nn (330000-340000)
# 2018-08-30 19:13:40,044 - root - INFO - produced batch 1
# 2018-08-30 19:13:44,780 - root - INFO - produced batch 2
# 2018-08-30 19:13:51,557 - root - INFO - produced batch 3
# 2018-08-30 19:14:05,054 - root - INFO - produced batch 4
# 2018-08-30 19:14:19,150 - root - INFO - produced batch 5
# 2018-08-30 19:14:28,253 - root - INFO - produced batch 6
# 2018-08-30 19:14:32,597 - root - INFO - produced batch 7
# 2018-08-30 19:14:40,026 - root - INFO - produced batch 8
# 2018-08-30 19:14:54,814 - root - INFO - produced batch 9
# 2018-08-30 19:15:17,257 - root - INFO - produced batch 10
# 2018-08-30 19:15:21,290 - root - INFO - running images through nn (340000-350000)
# 2018-08-30 19:15:26,138 - root - INFO - produced batch 1
# 2018-08-30 19:15:30,751 - root - INFO - produced batch 2
# 2018-08-30 19:15:40,392 - root - INFO - produced batch 3
# 2018-08-30 19:15:45,000 - root - INFO - produced batch 4
# 2018-08-30 19:15:49,430 - root - INFO - produced batch 5
# 2018-08-30 19:15:53,790 - root - INFO - produced batch 6
# 2018-08-30 19:15:58,138 - root - INFO - produced batch 7
# 2018-08-30 19:16:02,662 - root - INFO - produced batch 8
# 2018-08-30 19:16:07,566 - root - INFO - produced batch 9
# 2018-08-30 19:16:16,134 - root - INFO - produced batch 10
# 2018-08-30 19:16:20,264 - root - INFO - running images through nn (350000-360000)
# 2018-08-30 19:16:33,408 - root - INFO - produced batch 1
# 2018-08-30 19:16:38,623 - root - INFO - produced batch 2
# 2018-08-30 19:16:44,521 - root - INFO - produced batch 3
# 2018-08-30 19:16:54,490 - root - INFO - produced batch 4
# 2018-08-30 19:17:01,716 - root - INFO - produced batch 5
# 2018-08-30 19:17:06,358 - root - INFO - produced batch 6
# 2018-08-30 19:17:14,204 - root - INFO - produced batch 7
# 2018-08-30 19:17:27,664 - root - INFO - produced batch 8
# 2018-08-30 19:17:33,714 - root - INFO - produced batch 9
# 2018-08-30 19:17:42,361 - root - INFO - produced batch 10
# 2018-08-30 19:17:46,454 - root - INFO - running images through nn (360000-370000)
# 2018-08-30 19:17:54,327 - root - INFO - produced batch 1
# 2018-08-30 19:17:59,062 - root - INFO - produced batch 2
# 2018-08-30 19:18:03,432 - root - INFO - produced batch 3
# 2018-08-30 19:18:12,686 - root - INFO - produced batch 4
# 2018-08-30 19:18:17,794 - root - INFO - produced batch 5
# 2018-08-30 19:18:22,197 - root - INFO - produced batch 6
# 2018-08-30 19:18:26,582 - root - INFO - produced batch 7
# 2018-08-30 19:18:31,066 - root - INFO - produced batch 8
# 2018-08-30 19:18:34,979 - root - WARNING - Failed validation for /nn-images/images_split_by_domain/domains/kristendukephotography.com/2017-11-06-0de75828ebda1c7135f7a082119000f9fe571472.jpg. skipping.
# 2018-08-30 19:18:35,441 - root - INFO - produced batch 9
# 2018-08-30 19:18:39,767 - root - INFO - produced batch 10
# 2018-08-30 19:18:43,868 - root - INFO - running images through nn (370000-380000)
# 2018-08-30 19:18:49,714 - root - INFO - produced batch 1
# 2018-08-30 19:18:56,890 - root - INFO - produced batch 2
# 2018-08-30 19:19:02,417 - root - INFO - produced batch 3
# 2018-08-30 19:19:07,211 - root - INFO - produced batch 4
# 2018-08-30 19:19:12,539 - root - INFO - produced batch 5
# 2018-08-30 19:19:17,146 - root - INFO - produced batch 6
# 2018-08-30 19:19:33,579 - root - INFO - produced batch 7
# 2018-08-30 19:19:48,635 - root - INFO - produced batch 8
# 2018-08-30 19:19:55,144 - root - INFO - produced batch 9
# 2018-08-30 19:20:06,649 - root - INFO - produced batch 10
# 2018-08-30 19:20:10,672 - root - INFO - running images through nn (380000-390000)
# 2018-08-30 19:20:15,860 - root - INFO - produced batch 1
# 2018-08-30 19:20:23,790 - root - INFO - produced batch 2
# 2018-08-30 19:20:29,574 - root - INFO - produced batch 3
# 2018-08-30 19:20:38,982 - root - INFO - produced batch 4
# 2018-08-30 19:20:47,194 - root - INFO - produced batch 5
# 2018-08-30 19:20:55,434 - root - INFO - produced batch 6
# 2018-08-30 19:21:09,283 - root - INFO - produced batch 7
# 2018-08-30 19:21:15,710 - root - INFO - produced batch 8
# 2018-08-30 19:21:21,922 - root - INFO - produced batch 9
# 2018-08-30 19:22:06,472 - root - INFO - produced batch 10
# 2018-08-30 19:22:10,723 - root - INFO - running images through nn (390000-400000)
# 2018-08-30 19:22:18,788 - root - INFO - produced batch 1
# 2018-08-30 19:22:24,334 - root - INFO - produced batch 2
# 2018-08-30 19:22:33,738 - root - INFO - produced batch 3
# 2018-08-30 19:22:39,660 - root - INFO - produced batch 4
# 2018-08-30 19:22:44,022 - root - INFO - produced batch 5
# 2018-08-30 19:22:48,457 - root - INFO - produced batch 6
# 2018-08-30 19:22:52,902 - root - INFO - produced batch 7
# 2018-08-30 19:22:58,157 - root - INFO - produced batch 8
# 2018-08-30 19:23:05,793 - root - INFO - produced batch 9
# 2018-08-30 19:23:17,927 - root - INFO - produced batch 10
# 2018-08-30 19:23:22,005 - root - INFO - running images through nn (400000-410000)
# 2018-08-30 19:23:28,855 - root - INFO - produced batch 1
# 2018-08-30 19:23:39,546 - root - INFO - produced batch 2
# 2018-08-30 19:23:44,465 - root - INFO - produced batch 3
# 2018-08-30 19:23:52,809 - root - INFO - produced batch 4
# 2018-08-30 19:24:00,886 - root - INFO - produced batch 5
# 2018-08-30 19:24:07,842 - root - INFO - produced batch 6
# 2018-08-30 19:24:13,915 - root - INFO - produced batch 7
# 2018-08-30 19:24:20,332 - root - INFO - produced batch 8
# 2018-08-30 19:24:25,904 - root - INFO - produced batch 9
# 2018-08-30 19:24:30,222 - root - INFO - produced batch 10
# 2018-08-30 19:24:34,271 - root - INFO - running images through nn (410000-420000)
# 2018-08-30 19:24:44,795 - root - INFO - produced batch 1
# 2018-08-30 19:24:50,087 - root - INFO - produced batch 2
# 2018-08-30 19:24:55,475 - root - INFO - produced batch 3
# 2018-08-30 19:24:59,940 - root - INFO - produced batch 4
# 2018-08-30 19:25:06,715 - root - INFO - produced batch 5
# 2018-08-30 19:25:20,110 - root - INFO - produced batch 6
# 2018-08-30 19:25:33,034 - root - INFO - produced batch 7
# 2018-08-30 19:26:21,406 - root - INFO - produced batch 8
# 2018-08-30 19:26:26,774 - root - INFO - produced batch 9
# 2018-08-30 19:26:39,253 - root - INFO - produced batch 10
# 2018-08-30 19:26:43,355 - root - INFO - running images through nn (420000-430000)
# 2018-08-30 19:26:51,657 - root - INFO - produced batch 1
# 2018-08-30 19:26:57,756 - root - INFO - produced batch 2
# 2018-08-30 19:27:02,302 - root - INFO - produced batch 3
# 2018-08-30 19:27:08,810 - root - INFO - produced batch 4
# 2018-08-30 19:27:18,832 - root - INFO - produced batch 5
# 2018-08-30 19:27:24,719 - root - INFO - produced batch 6
# 2018-08-30 19:27:30,490 - root - INFO - produced batch 7
# 2018-08-30 19:27:35,443 - root - INFO - produced batch 8
# 2018-08-30 19:27:47,169 - root - INFO - produced batch 9
# 2018-08-30 19:27:55,832 - root - INFO - produced batch 10
# 2018-08-30 19:27:59,907 - root - INFO - running images through nn (430000-440000)
# 2018-08-30 19:28:05,048 - root - INFO - produced batch 1
# 2018-08-30 19:28:11,082 - root - INFO - produced batch 2
# 2018-08-30 19:28:18,958 - root - INFO - produced batch 3
# 2018-08-30 19:28:27,543 - root - INFO - produced batch 4
# 2018-08-30 19:28:35,378 - root - INFO - produced batch 5
# 2018-08-30 19:28:40,271 - root - INFO - produced batch 6
# 2018-08-30 19:28:44,753 - root - INFO - produced batch 7
# 2018-08-30 19:28:49,050 - root - INFO - produced batch 8
# 2018-08-30 19:28:53,340 - root - INFO - produced batch 9
# 2018-08-30 19:28:57,618 - root - INFO - produced batch 10
# 2018-08-30 19:29:01,729 - root - INFO - running images through nn (440000-450000)
# 2018-08-30 19:29:06,651 - root - INFO - produced batch 1
# 2018-08-30 19:29:11,309 - root - INFO - produced batch 2
# 2018-08-30 19:29:15,695 - root - INFO - produced batch 3
# 2018-08-30 19:29:20,056 - root - INFO - produced batch 4
# 2018-08-30 19:29:24,766 - root - INFO - produced batch 5
# 2018-08-30 19:29:29,189 - root - INFO - produced batch 6
# 2018-08-30 19:29:33,574 - root - INFO - produced batch 7
# 2018-08-30 19:29:37,927 - root - INFO - produced batch 8
# 2018-08-30 19:29:42,246 - root - INFO - produced batch 9
# 2018-08-30 19:29:46,535 - root - INFO - produced batch 10
# 2018-08-30 19:29:50,719 - root - INFO - running images through nn (450000-460000)
# 2018-08-30 19:29:55,587 - root - INFO - produced batch 1
# 2018-08-30 19:30:00,240 - root - INFO - produced batch 2
# 2018-08-30 19:30:05,750 - root - INFO - produced batch 3
# 2018-08-30 19:30:10,131 - root - INFO - produced batch 4
# 2018-08-30 19:30:14,570 - root - INFO - produced batch 5
# 2018-08-30 19:30:18,967 - root - INFO - produced batch 6
# 2018-08-30 19:30:23,360 - root - INFO - produced batch 7
# 2018-08-30 19:30:28,599 - root - INFO - produced batch 8
# 2018-08-30 19:30:34,086 - root - INFO - produced batch 9
# 2018-08-30 19:30:39,079 - root - INFO - produced batch 10
# 2018-08-30 19:30:43,148 - root - INFO - running images through nn (460000-470000)
# 2018-08-30 19:30:52,415 - root - INFO - produced batch 1
# 2018-08-30 19:31:00,302 - root - INFO - produced batch 2
# 2018-08-30 19:31:21,249 - root - INFO - produced batch 3
# 2018-08-30 19:31:40,346 - root - INFO - produced batch 4
# 2018-08-30 19:31:47,970 - root - INFO - produced batch 5
# 2018-08-30 19:31:52,422 - root - INFO - produced batch 6
# 2018-08-30 19:32:01,614 - root - INFO - produced batch 7
# 2018-08-30 19:32:13,435 - root - INFO - produced batch 8
# 2018-08-30 19:32:17,836 - root - INFO - produced batch 9
# 2018-08-30 19:32:22,149 - root - INFO - produced batch 10
# 2018-08-30 19:32:26,259 - root - INFO - running images through nn (470000-480000)
# 2018-08-30 19:32:43,737 - root - INFO - produced batch 1
# 2018-08-30 19:32:49,512 - root - INFO - produced batch 2
# 2018-08-30 19:32:58,943 - root - INFO - produced batch 3
# 2018-08-30 19:33:20,349 - root - INFO - produced batch 4
# 2018-08-30 19:33:24,912 - root - INFO - produced batch 5
# 2018-08-30 19:33:30,758 - root - INFO - produced batch 6
# 2018-08-30 19:33:49,107 - root - INFO - produced batch 7
# 2018-08-30 19:33:56,012 - root - INFO - produced batch 8
# 2018-08-30 19:34:02,773 - root - INFO - produced batch 9
# 2018-08-30 19:34:13,293 - root - INFO - produced batch 10
# 2018-08-30 19:34:17,386 - root - INFO - running images through nn (480000-490000)
# 2018-08-30 19:34:25,768 - root - INFO - produced batch 1
# 2018-08-30 19:34:37,449 - root - INFO - produced batch 2
# 2018-08-30 19:34:58,558 - root - INFO - produced batch 3
# 2018-08-30 19:35:07,506 - root - INFO - produced batch 4
# 2018-08-30 19:35:13,190 - root - INFO - produced batch 5
# 2018-08-30 19:35:20,442 - root - INFO - produced batch 6
# 2018-08-30 19:35:26,078 - root - INFO - produced batch 7
# 2018-08-30 19:35:32,460 - root - INFO - produced batch 8
# 2018-08-30 19:35:37,749 - root - INFO - produced batch 9
# 2018-08-30 19:35:43,343 - root - INFO - produced batch 10
# 2018-08-30 19:35:47,561 - root - INFO - running images through nn (490000-500000)
# 2018-08-30 19:35:52,255 - root - INFO - produced batch 1
# 2018-08-30 19:35:59,046 - root - INFO - produced batch 2
# 2018-08-30 19:36:03,711 - root - INFO - produced batch 3
# 2018-08-30 19:36:15,107 - root - INFO - produced batch 4
# 2018-08-30 19:36:20,099 - root - INFO - produced batch 5
# 2018-08-30 19:36:26,981 - root - INFO - produced batch 6
# 2018-08-30 19:36:32,407 - root - INFO - produced batch 7
# 2018-08-30 19:36:40,242 - root - INFO - produced batch 8
# 2018-08-30 19:36:45,547 - root - INFO - produced batch 9
# 2018-08-30 19:36:51,696 - root - INFO - produced batch 10
# 2018-08-30 19:36:55,803 - root - INFO - running images through nn (500000-510000)
# 2018-08-30 19:37:04,371 - root - INFO - produced batch 1
# 2018-08-30 19:37:13,235 - root - INFO - produced batch 2
# 2018-08-30 19:37:18,129 - root - INFO - produced batch 3
# 2018-08-30 19:37:24,591 - root - INFO - produced batch 4
# 2018-08-30 19:37:30,736 - root - INFO - produced batch 5
# 2018-08-30 19:37:39,359 - root - INFO - produced batch 6
# 2018-08-30 19:37:44,836 - root - INFO - produced batch 7
# 2018-08-30 19:37:50,312 - root - INFO - produced batch 8
# 2018-08-30 19:37:58,663 - root - INFO - produced batch 9
# 2018-08-30 19:38:06,896 - root - INFO - produced batch 10
# 2018-08-30 19:38:11,038 - root - INFO - running images through nn (510000-520000)
# 2018-08-30 19:38:17,250 - root - INFO - produced batch 1
# 2018-08-30 19:38:25,069 - root - INFO - produced batch 2
# 2018-08-30 19:38:30,118 - root - INFO - produced batch 3
# 2018-08-30 19:38:38,528 - root - INFO - produced batch 4
# 2018-08-30 19:38:52,219 - root - INFO - produced batch 5
# 2018-08-30 19:39:27,998 - root - INFO - produced batch 6
# 2018-08-30 19:39:36,300 - root - INFO - produced batch 7
# 2018-08-30 19:39:43,842 - root - INFO - produced batch 8
# 2018-08-30 19:39:52,819 - root - INFO - produced batch 9
# 2018-08-30 19:40:04,940 - root - INFO - produced batch 10
# 2018-08-30 19:40:09,224 - root - INFO - running images through nn (520000-530000)
# 2018-08-30 19:40:18,314 - root - INFO - produced batch 1
# 2018-08-30 19:40:24,926 - root - INFO - produced batch 2
# 2018-08-30 19:40:30,104 - root - INFO - produced batch 3
# 2018-08-30 19:40:36,303 - root - INFO - produced batch 4
# 2018-08-30 19:40:41,523 - root - INFO - produced batch 5
# 2018-08-30 19:40:47,902 - root - INFO - produced batch 6
# 2018-08-30 19:40:53,987 - root - INFO - produced batch 7
# 2018-08-30 19:41:10,906 - root - INFO - produced batch 8
# 2018-08-30 19:41:16,611 - root - INFO - produced batch 9
# 2018-08-30 19:41:23,377 - root - INFO - produced batch 10
# 2018-08-30 19:41:27,474 - root - INFO - running images through nn (530000-540000)
# 2018-08-30 19:41:36,843 - root - INFO - produced batch 1
# 2018-08-30 19:41:43,108 - root - INFO - produced batch 2
# 2018-08-30 19:41:48,329 - root - INFO - produced batch 3
# 2018-08-30 19:41:54,577 - root - INFO - produced batch 4
# 2018-08-30 19:42:00,107 - root - INFO - produced batch 5
# 2018-08-30 19:42:06,607 - root - INFO - produced batch 6
# 2018-08-30 19:42:12,555 - root - INFO - produced batch 7
# 2018-08-30 19:42:18,206 - root - INFO - produced batch 8
# 2018-08-30 19:42:23,555 - root - INFO - produced batch 9
# 2018-08-30 19:42:29,134 - root - INFO - produced batch 10
# 2018-08-30 19:42:33,310 - root - INFO - running images through nn (540000-550000)
# 2018-08-30 19:42:37,559 - root - INFO - produced batch 1
# 2018-08-30 19:42:51,358 - root - INFO - produced batch 2
# 2018-08-30 19:42:59,715 - root - INFO - produced batch 3
# 2018-08-30 19:43:08,087 - root - INFO - produced batch 4
# 2018-08-30 19:43:12,923 - root - INFO - produced batch 5
# 2018-08-30 19:43:20,042 - root - INFO - produced batch 6
# 2018-08-30 19:43:25,612 - root - INFO - produced batch 7
# 2018-08-30 19:43:30,070 - root - INFO - produced batch 8
# 2018-08-30 19:43:38,569 - root - INFO - produced batch 9
# 2018-08-30 19:43:51,899 - root - INFO - produced batch 10
# 2018-08-30 19:43:56,057 - root - INFO - running images through nn (550000-560000)
# 2018-08-30 19:44:02,975 - root - INFO - produced batch 1
# 2018-08-30 19:44:08,727 - root - INFO - produced batch 2
# 2018-08-30 19:44:16,762 - root - INFO - produced batch 3
# 2018-08-30 19:44:23,190 - root - INFO - produced batch 4
# 2018-08-30 19:44:31,547 - root - INFO - produced batch 5
# 2018-08-30 19:44:36,564 - root - INFO - produced batch 6
# 2018-08-30 19:44:44,101 - root - INFO - produced batch 7
# 2018-08-30 19:44:48,946 - root - INFO - produced batch 8
# 2018-08-30 19:44:54,627 - root - INFO - produced batch 9
# 2018-08-30 19:44:59,366 - root - INFO - produced batch 10
# 2018-08-30 19:45:03,441 - root - INFO - running images through nn (560000-570000)
# 2018-08-30 19:45:12,708 - root - INFO - produced batch 1
# 2018-08-30 19:45:19,728 - root - INFO - produced batch 2
# 2018-08-30 19:45:33,925 - root - INFO - produced batch 3
# 2018-08-30 19:45:43,710 - root - INFO - produced batch 4
# 2018-08-30 19:45:48,796 - root - INFO - produced batch 5
# 2018-08-30 19:45:54,723 - root - INFO - produced batch 6
# 2018-08-30 19:46:00,135 - root - INFO - produced batch 7
# 2018-08-30 19:46:11,854 - root - INFO - produced batch 8
# 2018-08-30 19:46:18,512 - root - INFO - produced batch 9
# 2018-08-30 19:46:23,707 - root - INFO - produced batch 10
# 2018-08-30 19:46:27,860 - root - INFO - running images through nn (570000-580000)
# 2018-08-30 19:46:33,539 - root - INFO - produced batch 1
# 2018-08-30 19:46:47,195 - root - INFO - produced batch 2
# 2018-08-30 19:46:51,090 - root - WARNING - Failed validation for /nn-images/images_split_by_domain/domains/kellystilwell.com/2014-01-13-4ffb93d7f7a37ef3cdc4778667f51b9fa19fa2b5.jpg. skipping.
# 2018-08-30 19:46:51,092 - root - WARNING - Failed validation for /nn-images/images_split_by_domain/domains/kellystilwell.com/2013-10-09-51e00ca1f4c1d931a93c56e19da2912c39bbabce.jpg. skipping.
# 2018-08-30 19:46:57,022 - root - INFO - produced batch 3
# 2018-08-30 19:47:05,999 - root - INFO - produced batch 4
# 2018-08-30 19:47:13,549 - root - INFO - produced batch 5
# 2018-08-30 19:47:21,961 - root - INFO - produced batch 6
# 2018-08-30 19:47:27,728 - root - INFO - produced batch 7
# 2018-08-30 19:47:35,737 - root - INFO - produced batch 8
# 2018-08-30 19:47:41,026 - root - INFO - produced batch 9
# 2018-08-30 19:47:47,765 - root - INFO - produced batch 10
# 2018-08-30 19:47:54,049 - root - INFO - running images through nn (580000-590000)
# 2018-08-30 19:48:01,863 - root - INFO - produced batch 1
# 2018-08-30 19:48:09,479 - root - INFO - produced batch 2
# 2018-08-30 19:48:13,854 - root - INFO - produced batch 3
# 2018-08-30 19:48:30,493 - root - INFO - produced batch 4
# 2018-08-30 19:48:36,188 - root - INFO - produced batch 5
# 2018-08-30 19:48:46,524 - root - INFO - produced batch 6
# 2018-08-30 19:48:55,228 - root - INFO - produced batch 7
# 2018-08-30 19:49:08,398 - root - INFO - produced batch 8
# 2018-08-30 19:49:13,415 - root - INFO - produced batch 9
# 2018-08-30 19:49:19,236 - root - INFO - produced batch 10
# 2018-08-30 19:49:23,339 - root - INFO - running images through nn (590000-600000)
# 2018-08-30 19:49:32,253 - root - INFO - produced batch 1
# 2018-08-30 19:49:38,484 - root - INFO - produced batch 2
# 2018-08-30 19:49:43,229 - root - INFO - produced batch 3
# 2018-08-30 19:49:54,185 - root - INFO - produced batch 4
# 2018-08-30 19:50:10,669 - root - INFO - produced batch 5
# 2018-08-30 19:50:17,314 - root - INFO - produced batch 6
# 2018-08-30 19:50:22,184 - root - INFO - produced batch 7
# 2018-08-30 19:50:29,199 - root - INFO - produced batch 8
# 2018-08-30 19:50:33,814 - root - INFO - produced batch 9
# 2018-08-30 19:50:39,990 - root - INFO - produced batch 10
# 2018-08-30 19:50:44,109 - root - INFO - running images through nn (600000-610000)
# 2018-08-30 19:50:54,486 - root - INFO - produced batch 1
# 2018-08-30 19:51:04,824 - root - INFO - produced batch 2

# %%
# validation_paths = glob.glob('data/*')
# with open('/nn-images/filenames/all_paths.pkl', 'rb') as f:
#     t = pickle.load(f)

# mscores = [mean_score(score) for score in scores]
# imnames = [p.split('/')[1][:-4] for p in validation_paths]
# score_dict = {n: s for s, n in zip(mscores, imnames)}

# %%
# with open('/nn-images/filenames/all_paths.pkl', 'rb') as f:
#     scored_paths = pickle.load(f)
    
# print(scores.shape, len(scored_paths))
# assert scores.shape[0] == len(scored_paths)

# with open('/nn-images/image_scores/scores.100.pkl', 'wb') as f:
#     pickle.dump((scores, scored_paths), f)

# %%
# last batch
#
# gap = 1000
# startidx = 807000
# endidx = len(ims)
# INPUT_PATHS = ims[startidx:endidx]
# RESHAPE_SIZE = (224, 224)

# logger.info(f'running images through nn ({startidx}-{endidx})')

# with warnings.catch_warnings():
#     warnings.simplefilter("ignore")
#     scores = model.predict_generator(nn_data_generator(1000), 1, verbose=2, workers=0)

# with open('/nn-images/filenames/all_paths.pkl', 'rb') as f:
#     scored_paths = pickle.load(f)

# assert scores.shape[0] == len(scored_paths)

# with open(f'/nn-images/image_scores/scores.{endidx:06}.pkl', 'wb') as f:
#     pickle.dump((scores, scored_paths), f)
# Out:
# 2018-08-30 21:35:45,153 - root - INFO - running images through nn (807000-807343)
# 2018-08-30 21:35:48,417 - root - INFO - produced batch 1
